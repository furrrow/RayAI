# %% [markdown]
# # Getting Started with RLLib! #
# https://docs.ray.io/en/latest/rllib/index.html#rllib-industry-grade-reinforcement-learning

# %%
from ray.rllib.algorithms.ppo import PPOConfig

config = (  # 1. Configure the algorithm,
    PPOConfig()
    .environment("Taxi-v3")
    .rollouts(num_rollout_workers=2)
    .framework("torch")
    .training(model={"fcnet_hiddens": [64, 64]})
    .evaluation(evaluation_num_workers=1)
)

algo = config.build()  # 2. build the algorithm,

for _ in range(5):
    print(algo.train())  # 3. train it,

algo.evaluate()  # 4. and evaluate it.
# Out:
# 2023-05-16 16:06:48,109	WARNING algorithm_config.py:784 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# 2023-05-16 16:06:49,761	INFO worker.py:1616 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# (RolloutWorker pid=36386) /home/jim/mambaforge/envs/ray/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
# (RolloutWorker pid=36386)   if not isinstance(terminated, (bool, np.bool8)):
# 2023-05-16 16:06:56,213	WARNING algorithm_config.py:784 -- You have specified 1 evaluation workers, but your `evaluation_interval` is None! Therefore, evaluation will not occur automatically with each call to `Algorithm.train()`. Instead, you will have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# 2023-05-16 16:06:57,883	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.10547825165733855, 'cur_kl_coeff': 0.20000000000000004, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.958843987987887, 'policy_loss': 0.010614987058184481, 'vf_loss': 9.94818369547526, 'vf_explained_var': -1.5098689704812983e-05, 'kl': 0.0002266533324108232, 'entropy': 1.7915336320477147, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0, 'num_grad_updates_lifetime': 465.5, 'diff_num_grad_updates_vs_sampler_policy': 464.5}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'sampler_results': {'episode_reward_max': -605.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -777.35, 'episode_len_mean': 200.0, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28544166932875725, 'mean_inference_ms': 0.8325787081473, 'mean_action_processing_ms': 0.10265832183243098, 'mean_env_wait_ms': 0.055677410604237684, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.015343427658081055, 'StateBufferConnector_ms': 0.0035238265991210938, 'ViewRequirementAgentConnector_ms': 0.08669137954711914}}, 'episode_reward_max': -605.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -777.35, 'episode_len_mean': 200.0, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28544166932875725, 'mean_inference_ms': 0.8325787081473, 'mean_action_processing_ms': 0.10265832183243098, 'mean_env_wait_ms': 0.055677410604237684, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.015343427658081055, 'StateBufferConnector_ms': 0.0035238265991210938, 'ViewRequirementAgentConnector_ms': 0.08669137954711914}, 'num_healthy_workers': 2, 'num_in_flight_async_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 4000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 4000, 'timers': {'training_iteration_time_ms': 5419.819, 'sample_time_ms': 2611.226, 'load_time_ms': 0.504, 'load_throughput': 7928741.021, 'learn_time_ms': 2806.032, 'learn_throughput': 1425.5, 'synch_weights_time_ms': 1.513}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'done': False, 'episodes_total': 20, 'training_iteration': 1, 'trial_id': 'default', 'date': '2023-05-16_16-07-03', 'timestamp': 1684267623, 'time_this_iter_s': 5.423591136932373, 'time_total_s': 5.423591136932373, 'pid': 35776, 'hostname': 'jim-desktop', 'node_ip': '192.168.0.135', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'num_gpus': 0, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, '_fake_gpus': False, 'num_learner_workers':  ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.13540489160485805, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.95135408011816, 'policy_loss': 0.007788773933525688, 'vf_loss': 9.943465444093109, 'vf_explained_var': -0.0001837620812077676, 'kl': 0.0009986998438871557, 'entropy': 1.7901989975283223, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0, 'num_grad_updates_lifetime': 1395.5, 'diff_num_grad_updates_vs_sampler_policy': 464.5}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'sampler_results': {'episode_reward_max': -264.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -756.675, 'episode_len_mean': 197.175, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28680723480582887, 'mean_inference_ms': 0.8318723935001792, 'mean_action_processing_ms': 0.10163868405556462, 'mean_env_wait_ms': 0.0554086467801435, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.015143156051635742, 'StateBufferConnector_ms': 0.0035494565963745117, 'ViewRequirementAgentConnector_ms': 0.08598208427429199}}, 'episode_reward_max': -264.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -756.675, 'episode_len_mean': 197.175, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28680723480582887, 'mean_inference_ms': 0.8318723935001792, 'mean_action_processing_ms': 0.10163868405556462, 'mean_env_wait_ms': 0.0554086467801435, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.015143156051635742, 'StateBufferConnector_ms': 0.0035494565963745117, 'ViewRequirementAgentConnector_ms': 0.08598208427429199}, 'num_healthy_workers': 2, 'num_in_flight_async_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'timesteps_total': 8000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 5398.733, 'sample_time_ms': 2607.991, 'load_time_ms': 0.849, 'load_throughput': 4713363.113, 'learn_time_ms': 2787.967, 'learn_throughput': 1434.737, 'synch_weights_time_ms': 1.404}, 'counters': {'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled' ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.17583113612947604, 'cur_kl_coeff': 0.05000000000000001, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.92987965614565, 'policy_loss': -0.003417861328950973, 'vf_loss': 9.932850464441444, 'vf_explained_var': -7.687531491761566e-05, 'kl': 0.008940884220688679, 'entropy': 1.77333392917469, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0, 'num_grad_updates_lifetime': 2325.5, 'diff_num_grad_updates_vs_sampler_policy': 464.5}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'sampler_results': {'episode_reward_max': -264.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -752.0166666666667, 'episode_len_mean': 198.11666666666667, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0, -776.0, -596.0, -758.0, -812.0, -821.0, -749.0, -758.0, -758.0, -677.0, -848.0, -668.0, -713.0, -848.0, -830.0, -677.0, -749.0, -848.0, -641.0, -623.0, -704.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28746768526207317, 'mean_inference_ms': 0.8316590395169174, 'mean_action_processing_ms': 0.10059859690207805, 'mean_env_wait_ms': 0.05527875475890853, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.016521612803141277, 'StateBufferConnector_ms': 0.003548860549926758, 'ViewRequirementAgentConnector_ms': 0.08554657300313313}}, 'episode_reward_max': -264.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -752.0166666666667, 'episode_len_mean': 198.11666666666667, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0, -776.0, -596.0, -758.0, -812.0, -821.0, -749.0, -758.0, -758.0, -677.0, -848.0, -668.0, -713.0, -848.0, -830.0, -677.0, -749.0, -848.0, -641.0, -623.0, -704.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28746768526207317, 'mean_inference_ms': 0.8316590395169174, 'mean_action_processing_ms': 0.10059859690207805, 'mean_env_wait_ms': 0.05527875475890853, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.016521612803141277, 'StateBufferConnector_ms': 0.003548860549926758, 'ViewRequirementAgentConnector_ms': 0.08554657300313313}, 'num_healthy_workers': 2, 'num_in_flight_async_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12 ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.26083301477214343, 'cur_kl_coeff': 0.05000000000000001, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.881177668417653, 'policy_loss': -0.007276194925064481, 'vf_loss': 9.888113080301592, 'vf_explained_var': 0.0001570433057764525, 'kl': 0.0068158396093802465, 'entropy': 1.7354016314270675, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0, 'num_grad_updates_lifetime': 3255.5, 'diff_num_grad_updates_vs_sampler_policy': 464.5}}, 'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000}, 'sampler_results': {'episode_reward_max': -231.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -723.6375, 'episode_len_mean': 197.325, 'episode_media': {}, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0, -776.0, -596.0, -758.0, -812.0, -821.0, -749.0, -758.0, -758.0, -677.0, -848.0, -668.0, -713.0, -848.0, -830.0, -677.0, -749.0, -848.0, -641.0, -623.0, -704.0, -677.0, -704.0, -659.0, -749.0, -650.0, -749.0, -623.0, -695.0, -695.0, -623.0, -713.0, -695.0, -578.0, -231.0, -686.0, -614.0, -614.0, -650.0, -605.0, -560.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 99, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.2882906620044274, 'mean_inference_ms': 0.8312331585603048, 'mean_action_processing_ms': 0.09983327043122574, 'mean_env_wait_ms': 0.055261664715622105, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.015876591205596924, 'StateBufferConnector_ms': 0.0034877657890319824, 'ViewRequirementAgentConnector_ms': 0.0859406590461731}}, 'episode_reward_max': -231.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -723.6375, 'episode_len_mean': 197.325, 'episodes_this_iter': 20, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-839.0, -875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0, -776.0, -596.0, -758.0, -812.0, -821.0, -749.0, -758.0, -758.0, -677.0, -848.0, -668.0, -713.0, -848.0, -830.0, -677.0, -749.0, -848.0, -641.0, -623.0, -704.0, -677.0, -704.0, -659.0, -749.0, -650.0, -749.0, -623.0, -695.0, -695.0, -623.0, -713.0, -695.0, -578.0, -231.0, -686.0, -614.0, -614.0, -650.0, -605.0, -560.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 99, 200, 200, 200, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.2882906620044274, 'mean_inference_ms': 0.8312331585603048,  ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 0.3246975289797911, 'cur_kl_coeff': 0.05000000000000001, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.895178328278245, 'policy_loss': -0.009087302588847697, 'vf_loss': 9.903919689629667, 'vf_explained_var': -0.0002465871713494742, 'kl': 0.006918934869861043, 'entropy': 1.6857218661615925, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 128.0, 'num_grad_updates_lifetime': 4185.5, 'diff_num_grad_updates_vs_sampler_policy': 464.5}}, 'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_agent_steps_sampled': 20000, 'num_agent_steps_trained': 20000}, 'sampler_results': {'episode_reward_max': -156.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -678.45, 'episode_len_mean': 195.81, 'episode_media': {}, 'episodes_this_iter': 21, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0, -776.0, -596.0, -758.0, -812.0, -821.0, -749.0, -758.0, -758.0, -677.0, -848.0, -668.0, -713.0, -848.0, -830.0, -677.0, -749.0, -848.0, -641.0, -623.0, -704.0, -677.0, -704.0, -659.0, -749.0, -650.0, -749.0, -623.0, -695.0, -695.0, -623.0, -713.0, -695.0, -578.0, -231.0, -686.0, -614.0, -614.0, -650.0, -605.0, -560.0, -533.0, -542.0, -560.0, -156.0, -542.0, -488.0, -533.0, -560.0, -560.0, -596.0, -524.0, -587.0, -515.0, -470.0, -488.0, -551.0, -587.0, -366.0, -452.0, -587.0, -596.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 87, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 99, 200, 200, 200, 200, 200, 200, 200, 200, 200, 69, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 126, 200, 200, 200]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.28879685666942806, 'mean_inference_ms': 0.8307772884561083, 'mean_action_processing_ms': 0.09959873268411137, 'mean_env_wait_ms': 0.05526759297540448, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.015396595001220703, 'StateBufferConnector_ms': 0.004337787628173828, 'ViewRequirementAgentConnector_ms': 0.08587217330932617}}, 'episode_reward_max': -156.0, 'episode_reward_min': -911.0, 'episode_reward_mean': -678.45, 'episode_len_mean': 195.81, 'episodes_this_iter': 21, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'hist_stats': {'episode_reward': [-875.0, -767.0, -830.0, -794.0, -722.0, -740.0, -740.0, -776.0, -812.0, -731.0, -767.0, -722.0, -605.0, -875.0, -740.0, -722.0, -731.0, -911.0, -848.0, -785.0, -713.0, -866.0, -803.0, -794.0, -264.0, -758.0, -758.0, -812.0, -785.0, -776.0, -632.0, -713.0, -695.0, -713.0, -749.0, -803.0, -776.0, -776.0, -749.0, -776.0, -596.0, -758.0, -812.0, -821.0, -749.0, -758.0, -758.0, -677.0, -848.0, -668.0, -713.0, -848.0, -830.0, -677.0, -749.0, -848.0, -641.0, -623.0, -704.0, -677.0, -704.0, -659.0, -749.0, -650.0, -749.0, -623.0, -695.0, -695.0, -623.0, -713.0, -695.0, -578.0, -231.0, -686.0, -614.0, -614.0, -650.0, -605.0, -560.0, -533.0, -542.0, -560.0, -156.0, -542.0, -488.0, -533.0, -560.0, -560.0, -596.0, -524.0, -587.0, -515.0, -470.0, -488.0, -551.0, -587.0, -366.0, -452.0, -587.0, -596.0], 'episode_lengths': [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 2 ...
# {'evaluation': {'episode_reward_max': -204.0,
#   'episode_reward_min': -614.0,
#   'episode_reward_mean': -451.5,
#   'episode_len_mean': 192.6,
#   'episode_media': {},
#   'episodes_this_iter': 10,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [-398.0,
#     -506.0,
#     -614.0,
#     -425.0,
#     -204.0,
#     -497.0,
#     -425.0,
#     -488.0,
#     -461.0,
#     -497.0],
#    'episode_lengths': [200, 200, 200, 200, 126, 200, 200, 200, 200, 200]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 0.1554996409314744,
#    'mean_inference_ms': 0.5064145480652332,
#    'mean_action_processing_ms': 0.06076357930078987,
#    'mean_env_wait_ms': 0.03786289945561836,
#    'mean_env_render_ms': 0.0},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {'ObsPreprocessorConnector_ms': 0.011317729949951172,
#    'StateBufferConnector_ms': 0.0025773048400878906,
#    'ViewRequirementAgentConnector_ms': 0.057146549224853516},
#   'num_agent_steps_sampled_this_iter': 1926,
#   'num_env_steps_sampled_this_iter': 1926,
#   'timesteps_this_iter': 1926}}
